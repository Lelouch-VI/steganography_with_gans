# %%
# Results
import pandas as pd

# Define the metrics from your output as lists
epochs = list(range(1, 17))
val_encoder_mse = [0.0251, 0.0182, 0.0162, 0.0139, 0.0131, 0.0122, 0.0112, 0.0114, 0.0107, 0.0098, 0.0093, 0.0122, 0.0094, 0.0090, 0.0080, 0.0085]
val_decoder_loss = [0.6563, 0.6151, 0.5776, 0.5487, 0.5121, 0.4862, 0.4605, 0.4392, 0.4201, 0.3955, 0.3746, 0.3672, 0.3487, 0.3313, 0.3218, 0.3063]
val_decoder_acc = [0.6483, 0.6860, 0.7101, 0.7310, 0.7535, 0.7701, 0.7864, 0.7985, 0.8098, 0.8232, 0.8324, 0.8365, 0.8471, 0.8549, 0.8601, 0.8665]
val_ssim = [0.6076, 0.6777, 0.6951, 0.7278, 0.7171, 0.7239, 0.7341, 0.7322, 0.7488, 0.7474, 0.7391, 0.7252, 0.7495, 0.7499, 0.7553, 0.7357]
val_psnr = [22.2158, 23.7007, 24.2101, 25.0382, 25.4293, 25.5654, 25.9523, 25.7916, 26.0593, 26.5209, 26.8505, 25.4199, 26.7053, 27.0175, 27.5391, 27.2032]
val_bpp = [0.8900, 1.1162, 1.2609, 1.3863, 1.5213, 1.6206, 1.7182, 1.7910, 1.8587, 1.9390, 1.9944, 2.0191, 2.0824, 2.1292, 2.1605, 2.1993]


# Create a DataFrame
df = pd.DataFrame({
    'Epoch': epochs,
    'Val Encoder MSE': val_encoder_mse,
    'Val Decoder Loss': val_decoder_loss,
    'Val Decoder Accuracy': val_decoder_acc,
    'Val SSIM': val_ssim,
    'Val PSNR': val_psnr,
    'Val BPP': val_bpp
})

# Display the table
print(df)
# Out:
#     Epoch  Val Encoder MSE  Val Decoder Loss  Val Decoder Accuracy  Val SSIM  \
# 0       1           0.0251            0.6563                0.6483    0.6076
# 1       2           0.0182            0.6151                0.6860    0.6777
# 2       3           0.0162            0.5776                0.7101    0.6951
# 3       4           0.0139            0.5487                0.7310    0.7278
# 4       5           0.0131            0.5121                0.7535    0.7171
# 5       6           0.0122            0.4862                0.7701    0.7239
# 6       7           0.0112            0.4605                0.7864    0.7341
# 7       8           0.0114            0.4392                0.7985    0.7322
# 8       9           0.0107            0.4201                0.8098    0.7488
# 9      10           0.0098            0.3955                0.8232    0.7474
# 10     11           0.0093            0.3746                0.8324    0.7391
# ...

# %%
#
import matplotlib.pyplot as plt

# Plot Val Encoder MSE
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val Encoder MSE'], marker='o')
plt.title('Validation Encoder MSE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val Encoder MSE')
plt.grid(True)
plt.show()

# Plot Val Decoder Loss
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val Decoder Loss'], marker='o')
plt.title('Validation Decoder Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val Decoder Loss')
plt.grid(True)
plt.show()

# Plot Val Decoder Accuracy
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val Decoder Accuracy'], marker='o')
plt.title('Validation Decoder Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val Decoder Accuracy')
plt.grid(True)
plt.show()

# Plot SSIM
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val SSIM'], marker='o')
plt.title('Validation SSIM Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val SSIM')
plt.grid(True)
plt.show()

# Plot PSNR
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val PSNR'], marker='o')
plt.title('Validation PSNR Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val PSNR')
plt.grid(True)
plt.show()

# Plot BPP
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Val BPP'], marker='o')
plt.title('Validation BPP Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Val BPP')
plt.grid(True)
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
    },
    'Residual': {
        'val.encoder_mse': [0.0314, 0.0224, 0.0183, 0.0155, 0.0143, 0.0129, 0.0133, 0.0127, 0.0110, 0.0103, 0.0099, 0.0102, 0.0106, 0.0098, 0.0088, 0.0086],
        'val.decoder_loss': [0.6683, 0.6395, 0.6201, 0.5921, 0.5677, 0.5366, 0.5118, 0.4751, 0.4499, 0.4270, 0.4042, 0.3859, 0.3664, 0.3558, 0.3300, 0.3182],
        'val.decoder_acc': [0.6296, 0.6703, 0.6864, 0.7040, 0.7195, 0.7393, 0.7560, 0.7755, 0.7917, 0.8060, 0.8184, 0.8288, 0.8376, 0.8442, 0.8564, 0.8619],
        'val.cover_score': [0.0309, 0.0438, 0.1272, 0.1248, 0.0907, 0.0887, 0.0481, 0.0640, 0.0282, 0.0275, 0.0244, 0.0976, 0.0666, 0.0213, 0.0268, 0.0436],
        'val.generated_score': [0.0310, 0.0490, 0.1275, 0.1259, 0.1001, 0.1138, 0.0820, 0.0832, 0.0364, 0.0292, 0.0277, 0.1094, 0.1239, 0.0233, 0.0306, 0.0644],
        'val.ssim': [0.5786, 0.6441, 0.6975, 0.7188, 0.7321, 0.7338, 0.7331, 0.7217, 0.7336, 0.7431, 0.7418, 0.7457, 0.7350, 0.7494, 0.7470, 0.7425],
        'val.psnr': [21.2219, 22.7494, 23.8356, 24.5079, 24.8583, 25.3903, 25.5062, 25.4649, 26.1143, 26.4250, 26.6805, 26.5303, 26.1523, 26.7529, 27.3100, 27.3927],
        'val.bpp': [0.7776, 1.0216, 1.1182, 1.2242, 1.3170, 1.4356, 1.5359, 1.6530, 1.7502, 1.8360, 1.9106, 1.9725, 2.0253, 2.0651, 2.1385, 2.1711],
    }
}

# Convert data to DataFrames
basic_df = pd.DataFrame(basic_critic_data)
dense_df = pd.DataFrame(dense_critic_data)
residual_df = pd.DataFrame(residual_critic_data)

# Plotting function
def plot_metrics(df, title):
    metrics = df.columns[1:]  # Exclude 'Epoch' from metrics
    epochs = df['Epoch']

    plt.figure(figsize=(14, 8))
    for metric in metrics:
        plt.plot(epochs, df[metric], label=metric)

    plt.xlabel('Epoch')
    plt.ylabel('Value')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to plot comparative graphs
def plot_comparative_metrics(metrics_data, metric_name, title, ylabel):
    epochs = range(1, 17)  # Assuming 16 epochs
    plt.figure(figsize=(10, 6))

    for critic, metrics in metrics_data.items():
        plt.plot(epochs, metrics[metric_name], label=f'{critic} Critic')

    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the comparative graphs
plot_comparative_metrics(metrics_data, 'val.encoder_mse', 'Validation Encoder MSE Across Critics', 'MSE')
plot_comparative_metrics(metrics_data, 'val.decoder_loss', 'Validation Decoder Loss Across Critics', 'Loss')
plot_comparative_metrics(metrics_data, 'val.decoder_acc', 'Validation Decoder Accuracy Across Critics', 'Accuracy')
plot_comparative_metrics(metrics_data, 'val.cover_score', 'Validation Cover Score Across Critics', 'Cover Score')
plot_comparative_metrics(metrics_data, 'val.generated_score', 'Validation Generated Score Across Critics', 'Generated Score')
plot_comparative_metrics(metrics_data, 'val.ssim', 'Validation SSIM Across Critics', 'SSIM')
plot_comparative_metrics(metrics_data, 'val.psnr', 'Validation PSNR Across Critics', 'PSNR')
plot_comparative_metrics(metrics_data, 'val.bpp', 'Validation BPP Across Critics', 'Bits Per Pixel')
